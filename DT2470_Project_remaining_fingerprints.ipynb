# %%
# !pip install pydub
# !pip install librosa
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.19.5)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pooch>=1.0->librosa) (1.24.3)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pydub
from scipy import signal
import librosa
import librosa.display

def get_samples(sound):
    channel_count = sound.channels
    if channel_count == 1:
        samples = np.array(sound.get_array_of_samples())
    elif channel_count == 2:
        sound_mono = sound.split_to_mono()
        samples = np.array(sound_mono[0].get_array_of_samples())
    else:
        raise Exception("More than 2 channels!")
    return samples

def plot_stft(t, f, dB, anchors=None):

    params = {'legend.fontsize': 'x-large','figure.figsize': (25, 6),
         'axes.labelsize': 'x-large','axes.titlesize':'x-large',
         'xtick.labelsize':'x-large','ytick.labelsize':'x-large'}
    plt.rcParams.update(params)

    fig = plt.figure()
    plt.pcolormesh(t, f, dB, cmap='YlOrRd', shading='auto')
    fig.suptitle('Short-time Fourier transform (window duration 50ms, hopsize 10 ms)')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (kHz)')
    plt.colorbar(format='%+02.0f dB')
    plt.ylim([0, 5])
    if anchors is not None:
        anchors_t, anchors_f = map(list, zip(*anchors))
        plt.scatter(anchors_t, anchors_f, marker='x', color='black')
    plt.show()
    
def generate_anchors(t, f, dB):
    delta_t = 0.1
    f_num_bands = 25

    t_rate = len(t) / (t[-1] - t[0])
    delta_i = int(delta_t * t_rate)
    if delta_i == 0:
        delta_i = 1
    delta_j = int(len(f) / f_num_bands)

    anchors_t = []
    anchors_f = []
    anchors = []

    for i in range(0, len(t) - delta_i, delta_i):
        for j in range(0, len(f) - delta_j, delta_j):
            tmp = dB[j:j+delta_j, i:i+delta_i]
            ind = np.unravel_index(np.argmax(tmp, axis=None), tmp.shape)
            anchors_t.append(t[i + ind[1]])
            anchors_f.append(f[j + ind[0]])
            anchors.append((t[i + ind[1]], f[j + ind[0]]))
    
    return anchors

def generate_fingerprint(anchors):
    F = []
    t_offset = 0.1
    t_window = 0.5
    f_factors = (2**-0.5, 2**0.5)

    anchors.sort(key=lambda x: x[0])
    for t1, f1 in anchors:
        t_min = t1 + t_offset
        t_max = t1 + t_offset + t_window
        f_min = f1 * f_factors[0]
        f_max = f1 * f_factors[1]
        for t2, f2 in anchors:
            if t2 < t_min or t2 > t_max or f2 < f_min or f2 > f_max:
                continue
            h = (f1, f2, t2 - t1)
            F.append((t1, h))
    
    return F

def generate_matches(F1, F2):
    matches = []
    h_range = range(len(F1[0][1]))
    for t1, h1 in F1:
        for t2, h2 in F2:
            match = True
            for i in h_range:
                if h1[i] != h2[i]:
                    match = False
                    break
            if match:
                matches.append((t1, t2))
    return matches

def generate_num_of_matches(F1, F2):
    num_of_matches = 0
    h_range = range(len(F1[0][1]))
    for t1, h1 in F1:
        for t2, h2 in F2:
            match = True
            for i in h_range:
                if h1[i] != h2[i]:
                    match = False
                    break
            if match:
                num_of_matches = num_of_matches + 1
    return num_of_matches

def plot_matches(matches, self_compare=False):
    params = {'legend.fontsize': 'x-large','figure.figsize': (12, 12),
            'axes.labelsize': 'x-large','axes.titlesize':'x-large',
            'xtick.labelsize':'x-large','ytick.labelsize':'x-large'}
    plt.rcParams.update(params)
    fig = plt.figure()
    matches_t1, matches_t2 = map(list, zip(*matches))
    plt.scatter(matches_t1, matches_t2, marker='x', color='black')
    plt.xlabel('Time in query signal (s)')
    if self_compare:
        plt.ylabel('Time in query signal (s)')
    else:
        plt.ylabel('Time in document signal (s)')
    plt.show()

# %%
def get_stft(snd_file, type = 0):
    if type == 0: sound = pydub.AudioSegment.from_file(snd_file, format="wav") 
    if type == 1: sound = pydub.AudioSegment.from_file(snd_file, format="m4a") 
    samples = get_samples(sound)
    duration = sound.duration_seconds
    window_ms = 50.0
    hop_ms = 10.0
    nperseg = (window_ms / 1000.0) * sound.frame_rate
    noverlap = ((window_ms - hop_ms) / 1000.0) * sound.frame_rate
    f, t, Zxx  = signal.stft(samples, fs = sound.frame_rate, window = 'hann', nperseg = nperseg, noverlap = noverlap, nfft = 50*4/1000*sound.frame_rate)
    f /= 1000.0
    dB = 20 * np.log10(np.abs(Zxx / abs(Zxx).max()))
    return t, f, dB

# %%
def get_fingerprint(snd_file, type = 0):
    t, f, dB = get_stft(snd_file, type)
    anchors = generate_anchors(t, f, dB)
    Fp = generate_fingerprint(anchors)
    return Fp

# %%
import pickle

# %%
for j in range(30):
    file = 'kiki' + str(j + 21) + '.pckl'
    f = open(file, 'wb')
    F_kiki_tmp_arr = []
    ran_min = (j + 20) * 10 + 1
    ran_max = (j + 21) * 10 + 1
    for i in range(ran_min, ran_max):
        index = str(i).zfill(4)
        kiki_file = "kiki_" + index + ".wav"
        F_kiki = get_fingerprint(kiki_file, 0)
        print("fingerprint generated: kiki_" + index)
        F_kiki_tmp_arr.append(F_kiki)
    pickle.dump(F_kiki_tmp_arr, f)
    f.close()
# Out:
# fingerprint generated: kiki_0201
# fingerprint generated: kiki_0202
# fingerprint generated: kiki_0203
# fingerprint generated: kiki_0204
# fingerprint generated: kiki_0205
# fingerprint generated: kiki_0206
# fingerprint generated: kiki_0207
# fingerprint generated: kiki_0208
# fingerprint generated: kiki_0209
# fingerprint generated: kiki_0210
# fingerprint generated: kiki_0211
# fingerprint generated: kiki_0212
# fingerprint generated: kiki_0213
# fingerprint generated: kiki_0214
# fingerprint generated: kiki_0215
# fingerprint generated: kiki_0216
# fingerprint generated: kiki_0217
# fingerprint generated: kiki_0218
# fingerprint generated: kiki_0219
# fingerprint generated: kiki_0220
# fingerprint generated: kiki_0221
# fingerprint generated: kiki_0222
# fingerprint generated: kiki_0223
# fingerprint generated: kiki_0224
# fingerprint generated: kiki_0225
# fingerprint generated: kiki_0226
# fingerprint generated: kiki_0227
# fingerprint generated: kiki_0228
# fingerprint generated: kiki_0229
# fingerprint generated: kiki_0230
# fingerprint generated: kiki_0231
# fingerprint generated: kiki_0232
# fingerprint generated: kiki_0233
# fingerprint generated: kiki_0234
# fingerprint generated: kiki_0235
# fingerprint generated: kiki_0236
# fingerprint generated: kiki_0237
# fingerprint generated: kiki_0238
# fingerprint generated: kiki_0239
# fingerprint generated: kiki_0240
# fingerprint generated: kiki_0241
# fingerprint generated: kiki_0242
# fingerprint generated: kiki_0243
# fingerprint generated: kiki_0244
# fingerprint generated: kiki_0245
# fingerprint generated: kiki_0246
# fingerprint generated: kiki_0247
# fingerprint generated: kiki_0248
# fingerprint generated: kiki_0249
# fingerprint generated: kiki_0250
# fingerprint generated: kiki_0251
# fingerprint generated: kiki_0252
# fingerprint generated: kiki_0253
# fingerprint generated: kiki_0254
# fingerprint generated: kiki_0255
# fingerprint generated: kiki_0256
# fingerprint generated: kiki_0257
# fingerprint generated: kiki_0258
# fingerprint generated: kiki_0259
# fingerprint generated: kiki_0260
# fingerprint generated: kiki_0261
# fingerprint generated: kiki_0262
# fingerprint generated: kiki_0263
# fingerprint generated: kiki_0264
# fingerprint generated: kiki_0265
# fingerprint generated: kiki_0266
# fingerprint generated: kiki_0267
# fingerprint generated: kiki_0268
# fingerprint generated: kiki_0269
# fingerprint generated: kiki_0270
# fingerprint generated: kiki_0271
# fingerprint generated: kiki_0272
# fingerprint generated: kiki_0273
# fingerprint generated: kiki_0274
# fingerprint generated: kiki_0275
# fingerprint generated: kiki_0276
# fingerprint generated: kiki_0277
# fingerprint generated: kiki_0278
# fingerprint generated: kiki_0279
# fingerprint generated: kiki_0280
# fingerprint generated: kiki_0281
# fingerprint generated: kiki_0282
# fingerprint generated: kiki_0283
# fingerprint generated: kiki_0284
# fingerprint generated: kiki_0285
# fingerprint generated: kiki_0286
# fingerprint generated: kiki_0287
# fingerprint generated: kiki_0288
# fingerprint generated: kiki_0289
# fingerprint generated: kiki_0290
# fingerprint generated: kiki_0291
# fingerprint generated: kiki_0292
# fingerprint generated: kiki_0293
# fingerprint generated: kiki_0294
# fingerprint generated: kiki_0295
# fingerprint generated: kiki_0296
# fingerprint generated: kiki_0297
# fingerprint generated: kiki_0298
# fingerprint generated: kiki_0299
# fingerprint generated: kiki_0300
# fingerprint generated: kiki_0301
# fingerprint generated: kiki_0302
# fingerprint generated: kiki_0303
# fingerprint generated: kiki_0304
# fingerprint generated: kiki_0305
# fingerprint generated: kiki_0306
# fingerprint generated: kiki_0307
# fingerprint generated: kiki_0308
# fingerprint generated: kiki_0309
# fingerprint generated: kiki_0310
# fingerprint generated: kiki_0311
# fingerprint generated: kiki_0312
# fingerprint generated: kiki_0313
# fingerprint generated: kiki_0314
# fingerprint generated: kiki_0315
# fingerprint generated: kiki_0316
# fingerprint generated: kiki_0317
# fingerprint generated: kiki_0318
# fingerprint generated: kiki_0319
# fingerprint generated: kiki_0320
# fingerprint generated: kiki_0321
# fingerprint generated: kiki_0322
# fingerprint generated: kiki_0323
# fingerprint generated: kiki_0324
# fingerprint generated: kiki_0325
# fingerprint generated: kiki_0326
# fingerprint generated: kiki_0327
# fingerprint generated: kiki_0328
# fingerprint generated: kiki_0329
# fingerprint generated: kiki_0330
# fingerprint generated: kiki_0331
# fingerprint generated: kiki_0332
# fingerprint generated: kiki_0333
# fingerprint generated: kiki_0334
# fingerprint generated: kiki_0335
# fingerprint generated: kiki_0336
# fingerprint generated: kiki_0337
# fingerprint generated: kiki_0338
# fingerprint generated: kiki_0339
# fingerprint generated: kiki_0340
# fingerprint generated: kiki_0341
# fingerprint generated: kiki_0342
# fingerprint generated: kiki_0343
# fingerprint generated: kiki_0344
# fingerprint generated: kiki_0345
# fingerprint generated: kiki_0346
# fingerprint generated: kiki_0347
# fingerprint generated: kiki_0348
# fingerprint generated: kiki_0349
# fingerprint generated: kiki_0350
# fingerprint generated: kiki_0351
# fingerprint generated: kiki_0352
# fingerprint generated: kiki_0353
# fingerprint generated: kiki_0354
# fingerprint generated: kiki_0355
# fingerprint generated: kiki_0356
# fingerprint generated: kiki_0357
# fingerprint generated: kiki_0358
# fingerprint generated: kiki_0359
# fingerprint generated: kiki_0360
# fingerprint generated: kiki_0361
# fingerprint generated: kiki_0362
# fingerprint generated: kiki_0363
# fingerprint generated: kiki_0364
# fingerprint generated: kiki_0365
# fingerprint generated: kiki_0366
# fingerprint generated: kiki_0367
# fingerprint generated: kiki_0368
# fingerprint generated: kiki_0369
# fingerprint generated: kiki_0370
# fingerprint generated: kiki_0371
# fingerprint generated: kiki_0372
# fingerprint generated: kiki_0373
# fingerprint generated: kiki_0374
# fingerprint generated: kiki_0375
# fingerprint generated: kiki_0376
# fingerprint generated: kiki_0377
# fingerprint generated: kiki_0378
# fingerprint generated: kiki_0379
# fingerprint generated: kiki_0380
# fingerprint generated: kiki_0381
# fingerprint generated: kiki_0382
# fingerprint generated: kiki_0383
# fingerprint generated: kiki_0384
# fingerprint generated: kiki_0385
# fingerprint generated: kiki_0386
# fingerprint generated: kiki_0387
# fingerprint generated: kiki_0388
# fingerprint generated: kiki_0389
# fingerprint generated: kiki_0390
# fingerprint generated: kiki_0391
# fingerprint generated: kiki_0392
# fingerprint generated: kiki_0393
# fingerprint generated: kiki_0394
# fingerprint generated: kiki_0395
# fingerprint generated: kiki_0396
# fingerprint generated: kiki_0397
# fingerprint generated: kiki_0398
# fingerprint generated: kiki_0399
# fingerprint generated: kiki_0400
# fingerprint generated: kiki_0401
# fingerprint generated: kiki_0402
# fingerprint generated: kiki_0403
# fingerprint generated: kiki_0404
# fingerprint generated: kiki_0405
# fingerprint generated: kiki_0406
# fingerprint generated: kiki_0407
# fingerprint generated: kiki_0408
# fingerprint generated: kiki_0409
# fingerprint generated: kiki_0410
# fingerprint generated: kiki_0411
# fingerprint generated: kiki_0412
# fingerprint generated: kiki_0413
# fingerprint generated: kiki_0414
# fingerprint generated: kiki_0415
# fingerprint generated: kiki_0416
# fingerprint generated: kiki_0417
# fingerprint generated: kiki_0418
# fingerprint generated: kiki_0419
# fingerprint generated: kiki_0420
# fingerprint generated: kiki_0421
# fingerprint generated: kiki_0422
# fingerprint generated: kiki_0423
# fingerprint generated: kiki_0424
# fingerprint generated: kiki_0425
# fingerprint generated: kiki_0426
# fingerprint generated: kiki_0427
# fingerprint generated: kiki_0428
# fingerprint generated: kiki_0429
# fingerprint generated: kiki_0430
# fingerprint generated: kiki_0431
# fingerprint generated: kiki_0432
# fingerprint generated: kiki_0433
# fingerprint generated: kiki_0434
# fingerprint generated: kiki_0435
# fingerprint generated: kiki_0436
# fingerprint generated: kiki_0437
# fingerprint generated: kiki_0438
# fingerprint generated: kiki_0439
# fingerprint generated: kiki_0440
# fingerprint generated: kiki_0441
# fingerprint generated: kiki_0442
# fingerprint generated: kiki_0443
# fingerprint generated: kiki_0444
# fingerprint generated: kiki_0445
# fingerprint generated: kiki_0446
# fingerprint generated: kiki_0447
# fingerprint generated: kiki_0448
# fingerprint generated: kiki_0449
# fingerprint generated: kiki_0450
# fingerprint generated: kiki_0451
# fingerprint generated: kiki_0452
# fingerprint generated: kiki_0453
# fingerprint generated: kiki_0454
# fingerprint generated: kiki_0455
# fingerprint generated: kiki_0456
# fingerprint generated: kiki_0457
# fingerprint generated: kiki_0458
# fingerprint generated: kiki_0459
# fingerprint generated: kiki_0460
# fingerprint generated: kiki_0461
# fingerprint generated: kiki_0462
# fingerprint generated: kiki_0463
# fingerprint generated: kiki_0464
# fingerprint generated: kiki_0465
# fingerprint generated: kiki_0466
# fingerprint generated: kiki_0467
# fingerprint generated: kiki_0468
# fingerprint generated: kiki_0469
# fingerprint generated: kiki_0470
# fingerprint generated: kiki_0471
# fingerprint generated: kiki_0472
# fingerprint generated: kiki_0473
# fingerprint generated: kiki_0474
# fingerprint generated: kiki_0475
# fingerprint generated: kiki_0476
# fingerprint generated: kiki_0477
# fingerprint generated: kiki_0478
# fingerprint generated: kiki_0479
# fingerprint generated: kiki_0480
# fingerprint generated: kiki_0481
# fingerprint generated: kiki_0482
# fingerprint generated: kiki_0483
# fingerprint generated: kiki_0484
# fingerprint generated: kiki_0485
# fingerprint generated: kiki_0486
# fingerprint generated: kiki_0487
# fingerprint generated: kiki_0488
# fingerprint generated: kiki_0489
# fingerprint generated: kiki_0490
# fingerprint generated: kiki_0491
# fingerprint generated: kiki_0492
# fingerprint generated: kiki_0493
# fingerprint generated: kiki_0494
# fingerprint generated: kiki_0495
# fingerprint generated: kiki_0496
# fingerprint generated: kiki_0497
# fingerprint generated: kiki_0498
# fingerprint generated: kiki_0499
# fingerprint generated: kiki_0500

# %%
# !zip -r 'NewFileName1.zip' 'kiki21.pckl'
# !zip -r 'NewFileName1.zip' 'kiki22.pckl'
# !zip -r 'NewFileName1.zip' 'kiki23.pckl'
# !zip -r 'NewFileName1.zip' 'kiki24.pckl'
# !zip -r 'NewFileName1.zip' 'kiki25.pckl'
# !zip -r 'NewFileName1.zip' 'kiki26.pckl'
# !zip -r 'NewFileName1.zip' 'kiki27.pckl'
# !zip -r 'NewFileName1.zip' 'kiki28.pckl'
# !zip -r 'NewFileName1.zip' 'kiki29.pckl'
# !zip -r 'NewFileName1.zip' 'kiki30.pckl'
# !zip -r 'NewFileName1.zip' 'kiki31.pckl'
# !zip -r 'NewFileName1.zip' 'kiki32.pckl'
# !zip -r 'NewFileName1.zip' 'kiki33.pckl'
# !zip -r 'NewFileName1.zip' 'kiki34.pckl'
# !zip -r 'NewFileName1.zip' 'kiki35.pckl'
# !zip -r 'NewFileName1.zip' 'kiki36.pckl'
# !zip -r 'NewFileName1.zip' 'kiki37.pckl'
# !zip -r 'NewFileName1.zip' 'kiki38.pckl'
# !zip -r 'NewFileName1.zip' 'kiki39.pckl'
# !zip -r 'NewFileName1.zip' 'kiki40.pckl'
# !zip -r 'NewFileName1.zip' 'kiki41.pckl'
# !zip -r 'NewFileName1.zip' 'kiki42.pckl'
# !zip -r 'NewFileName1.zip' 'kiki43.pckl'
# !zip -r 'NewFileName1.zip' 'kiki44.pckl'
# !zip -r 'NewFileName1.zip' 'kiki45.pckl'
# !zip -r 'NewFileName1.zip' 'kiki46.pckl'
# !zip -r 'NewFileName1.zip' 'kiki47.pckl'
# !zip -r 'NewFileName1.zip' 'kiki48.pckl'
# !zip -r 'NewFileName1.zip' 'kiki49.pckl'
# !zip -r 'NewFileName1.zip' 'kiki50.pckl'
# Out:
#   adding: kiki21.pckl (deflated 75%)
#   adding: kiki22.pckl (deflated 75%)
#   adding: kiki23.pckl (deflated 75%)
#   adding: kiki24.pckl (deflated 75%)
#   adding: kiki25.pckl (deflated 75%)
#   adding: kiki26.pckl (deflated 75%)
#   adding: kiki27.pckl (deflated 75%)
#   adding: kiki28.pckl (deflated 75%)
#   adding: kiki29.pckl (deflated 75%)
#   adding: kiki30.pckl (deflated 75%)
#   adding: kiki31.pckl (deflated 75%)
#   adding: kiki32.pckl (deflated 75%)
#   adding: kiki33.pckl (deflated 75%)
#   adding: kiki34.pckl (deflated 75%)
#   adding: kiki35.pckl (deflated 75%)
#   adding: kiki36.pckl (deflated 75%)
#   adding: kiki37.pckl (deflated 75%)
#   adding: kiki38.pckl (deflated 75%)
#   adding: kiki39.pckl (deflated 75%)
#   adding: kiki40.pckl (deflated 75%)
#   adding: kiki41.pckl (deflated 75%)
#   adding: kiki42.pckl (deflated 75%)
#   adding: kiki43.pckl (deflated 75%)
#   adding: kiki44.pckl (deflated 75%)
#   adding: kiki45.pckl (deflated 75%)
#   adding: kiki46.pckl (deflated 75%)
#   adding: kiki47.pckl (deflated 75%)
#   adding: kiki48.pckl (deflated 75%)
#   adding: kiki49.pckl (deflated 75%)
#   adding: kiki50.pckl (deflated 75%)

# %%
for j in range(30):
    file = 'bouba' + str(j + 21) + '.pckl'
    f = open(file, 'wb')
    F_bouba_tmp_arr = []
    ran_min = (j + 20) * 10 + 1
    ran_max = (j + 21) * 10 + 1
    for i in range(ran_min, ran_max):
        index = str(i).zfill(4)
        bouba_file = "bouba_" + index + ".wav"
        F_bouba = get_fingerprint(bouba_file, 0)
        print("fingerprint generated: bouba_" + index)
        F_bouba_tmp_arr.append(F_bouba)
    pickle.dump(F_bouba_tmp_arr, f)
    f.close()
# Out:
# fingerprint generated: bouba_0201
# fingerprint generated: bouba_0202
# fingerprint generated: bouba_0203
# fingerprint generated: bouba_0204
# fingerprint generated: bouba_0205
# fingerprint generated: bouba_0206
# fingerprint generated: bouba_0207
# fingerprint generated: bouba_0208
# fingerprint generated: bouba_0209
# fingerprint generated: bouba_0210
# fingerprint generated: bouba_0211
# fingerprint generated: bouba_0212
# fingerprint generated: bouba_0213
# !zip -r 'NewFileName1.zip' 'bouba22.pckl'
# !zip -r 'NewFileName1.zip' 'bouba23.pckl'
# !zip -r 'NewFileName1.zip' 'bouba24.pckl'
# !zip -r 'NewFileName1.zip' 'bouba25.pckl'
# !zip -r 'NewFileName1.zip' 'bouba26.pckl'
# !zip -r 'NewFileName1.zip' 'bouba27.pckl'
# !zip -r 'NewFileName1.zip' 'bouba28.pckl'
# !zip -r 'NewFileName1.zip' 'bouba29.pckl'
# !zip -r 'NewFileName1.zip' 'bouba30.pckl'
# !zip -r 'NewFileName1.zip' 'bouba31.pckl'
# !zip -r 'NewFileName1.zip' 'bouba32.pckl'
# !zip -r 'NewFileName1.zip' 'bouba33.pckl'
# !zip -r 'NewFileName1.zip' 'bouba34.pckl'
# !zip -r 'NewFileName1.zip' 'bouba35.pckl'
# !zip -r 'NewFileName1.zip' 'bouba36.pckl'
# !zip -r 'NewFileName1.zip' 'bouba37.pckl'
# !zip -r 'NewFileName1.zip' 'bouba38.pckl'
# !zip -r 'NewFileName1.zip' 'bouba39.pckl'
# !zip -r 'NewFileName1.zip' 'bouba40.pckl'
# !zip -r 'NewFileName1.zip' 'bouba41.pckl'
# !zip -r 'NewFileName1.zip' 'bouba42.pckl'
# !zip -r 'NewFileName1.zip' 'bouba43.pckl'
# !zip -r 'NewFileName1.zip' 'bouba44.pckl'
# !zip -r 'NewFileName1.zip' 'bouba45.pckl'
# !zip -r 'NewFileName1.zip' 'bouba46.pckl'
# !zip -r 'NewFileName1.zip' 'bouba47.pckl'
# !zip -r 'NewFileName1.zip' 'bouba48.pckl'
# !zip -r 'NewFileName1.zip' 'bouba49.pckl'
# !zip -r 'NewFileName1.zip' 'bouba50.pckl'
# Out:
#   adding: bouba21.pckl (deflated 74%)
#   adding: bouba22.pckl (deflated 74%)
#   adding: bouba23.pckl (deflated 74%)
#   adding: bouba24.pckl (deflated 74%)
#   adding: bouba25.pckl (deflated 74%)
#   adding: bouba26.pckl (deflated 74%)
#   adding: bouba27.pckl (deflated 74%)
#   adding: bouba28.pckl (deflated 74%)
#   adding: bouba29.pckl (deflated 74%)
#   adding: bouba30.pckl (deflated 74%)
#   adding: bouba31.pckl (deflated 74%)
#   adding: bouba32.pckl (deflated 74%)
#   adding: bouba33.pckl (deflated 74%)
#   adding: bouba34.pckl (deflated 74%)
#   adding: bouba35.pckl (deflated 74%)
#   adding: bouba36.pckl (deflated 74%)
#   adding: bouba37.pckl (deflated 74%)
#   adding: bouba38.pckl (deflated 74%)
#   adding: bouba39.pckl (deflated 74%)
#   adding: bouba40.pckl (deflated 74%)
#   adding: bouba41.pckl (deflated 74%)
#   adding: bouba42.pckl (deflated 74%)
#   adding: bouba43.pckl (deflated 74%)
#   adding: bouba44.pckl (deflated 74%)
#   adding: bouba45.pckl (deflated 74%)
#   adding: bouba46.pckl (deflated 74%)
#   adding: bouba47.pckl (deflated 74%)
#   adding: bouba48.pckl (deflated 74%)
#   adding: bouba49.pckl (deflated 74%)
#   adding: bouba50.pckl (deflated 74%)
